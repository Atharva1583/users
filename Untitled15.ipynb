# %%
import pandas as pd
df=pd.read_csv("./1_boston_housing.csv")

# %%
df
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90   5.33  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     506 non-null    float64
#  1   zn       506 non-null    float64
#  2   indus    506 non-null    float64
#  3   chas     506 non-null    int64
#  4   nox      506 non-null    float64
#  5   rm       506 non-null    float64
#  6   age      506 non-null    float64
#  7   dis      506 non-null    float64
#  8   rad      506 non-null    int64
#  9   tax      506 non-null    int64
#  10  ptratio  506 non-null    float64
#  11  b        506 non-null    float64
#  12  lstat    506 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
from sklearn.model_selection import train_test_split

# %%
X=df.loc[:,df.columns!='MEDV']
y=df.loc[:,df.columns=='MEDV']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=123)

# %%
from sklearn.preprocessing import MinMaxScaler
mms=MinMaxScaler()
mms.fit(X_train)
X_train=mms.transform(X_train)
X_test=mms.transform(X_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model=Sequential()

model.add(Dense(128,input_shape=(13, ),activation='relu',name='dense_1'))
model.add(Dense(64,activation='relu',name='dense_2'))
model.add(Dense(1,activation='linear',name='dense_output'))
model.compile(optimizer='adam',loss='mse',metrics=['mae'])
model.summary()
# Out:
# C:\Users\Icon\anaconda3\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_1 (Dense)                 │ (None, 128)            │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_output (Dense)            │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 10,113 (39.50 KB)
#  Trainable params: 10,113 (39.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history=model.fit(X_train,y_train,epochs=100,validation_split=0.05,verbose=1)
# Out:
# Epoch 1/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 573.7347 - mae: 22.0686 - val_loss: 591.2225 - val_mae: 22.3530
# Epoch 2/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 525.2480 - mae: 20.8463 - val_loss: 538.1975 - val_mae: 21.0848
# Epoch 3/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 466.0173 - mae: 19.2161 - val_loss: 459.7874 - val_mae: 19.0452
# Epoch 4/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 367.8972 - mae: 16.7597 - val_loss: 353.0180 - val_mae: 15.8085
# Epoch 5/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 279.2374 - mae: 13.6045 - val_loss: 236.5541 - val_mae: 11.9130
# Epoch 6/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 194.8327 - mae: 11.1750 - val_loss: 155.8012 - val_mae: 8.6736
# Epoch 7/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 140.6704 - mae: 9.3702 - val_loss: 129.9963 - val_mae: 8.3372
# Epoch 8/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 130.3698 - mae: 8.8783 - val_loss: 119.0612 - val_mae: 7.9768
# Epoch 9/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 113.8628 - mae: 8.2208 - val_loss: 111.9082 - val_mae: 7.5988
# Epoch 10/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 101.9867 - mae: 7.6280 - val_loss: 103.5015 - val_mae: 7.2226
# Epoch 11/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 86.3403 - mae: 6.8088 - val_loss: 94.2372 - val_mae: 6.8568
# Epoch 12/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 84.7429 - mae: 6.8367 - val_loss: 86.6108 - val_mae: 6.5636
# Epoch 13/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 69.1033 - mae: 6.0484 - val_loss: 82.0109 - val_mae: 6.2245
# Epoch 14/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 65.7345 - mae: 5.8405 - val_loss: 77.3355 - val_mae: 6.1418
# Epoch 15/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 55.7905 - mae: 5.2962 - val_loss: 74.0572 - val_mae: 6.0928
# Epoch 16/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 46.7592 - mae: 4.9405 - val_loss: 71.3548 - val_mae: 6.0447
# Epoch 17/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 49.0740 - mae: 5.0433 - val_loss: 68.4739 - val_mae: 6.1228
# Epoch 18/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 44.7425 - mae: 4.8112 - val_loss: 66.7781 - val_mae: 5.9674
# Epoch 19/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 44.7812 - mae: 4.6057 - val_loss: 65.6376 - val_mae: 5.7919
# Epoch 20/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 47.8734 - mae: 4.9353 - val_loss: 63.3058 - val_mae: 5.8299
# Epoch 21/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 39.9961 - mae: 4.4267 - val_loss: 62.0988 - val_mae: 5.6547
# Epoch 22/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 37.9709 - mae: 4.3308 - val_loss: 61.0647 - val_mae: 5.5074
# Epoch 23/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 40.5704 - mae: 4.2854 - val_loss: 58.8090 - val_mae: 5.5353
# Epoch 24/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 34.4604 - mae: 4.1913 - val_loss: 56.9926 - val_mae: 5.4450
# Epoch 25/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 37.4262 - mae: 4.2265 - val_loss: 54.9253 - val_mae: 5.4012
# Epoch 26/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 31.4086 - mae: 3.9033 - val_loss: 54.7473 - val_mae: 5.1573
# Epoch 27/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 34.1985 - mae: 4.0065 - val_loss: 53.6843 - val_mae: 5.0428
# Epoch 28/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 33.4013 - mae: 3.9615 - val_loss: 50.1649 - val_mae: 5.1404
# Epoch 29/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 33.4527 - mae: 3.9598 - val_loss: 50.1945 - val_mae: 4.9062
# Epoch 30/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 30.5837 - mae: 3.7470 - val_loss: 48.1482 - val_mae: 4.8819
# Epoch 31/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 24.6365 - mae: 3.4948 - val_loss: 46.2677 - val_mae: 4.8657
# Epoch 32/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 25.6640 - mae: 3.5884 - val_loss: 46.3345 - val_mae: 4.8124
# Epoch 33/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 23.8964 - mae: 3.3753 - val_loss: 44.1782 - val_mae: 4.7915
# Epoch 34/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 21.4313 - mae: 3.2748 - val_loss: 43.7092 - val_mae: 4.7460
# Epoch 35/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 23.8449 - mae: 3.4849 - val_loss: 41.8400 - val_mae: 4.7073
# Epoch 36/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 20.6845 - mae: 3.2567 - val_loss: 42.0469 - val_mae: 4.6491
# Epoch 37/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 25.8944 - mae: 3.4839 - val_loss: 40.9894 - val_mae: 4.6063
# Epoch 38/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 17.3635 - mae: 2.9204 - val_loss: 40.2583 - val_mae: 4.5642
# Epoch 39/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 18.8127 - mae: 3.1299 - val_loss: 39.4479 - val_mae: 4.5179
# Epoch 40/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 18.5101 - mae: 3.0961 - val_loss: 39.5746 - val_mae: 4.4785
# Epoch 41/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 20.2560 - mae: 3.0934 - val_loss: 37.9737 - val_mae: 4.4472
# Epoch 42/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 23.0758 - mae: 3.1613 - val_loss: 38.4053 - val_mae: 4.3736
# Epoch 43/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 17.7306 - mae: 2.8367 - val_loss: 37.2030 - val_mae: 4.3284
# Epoch 44/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 23.7506 - mae: 3.2418 - val_loss: 37.1630 - val_mae: 4.2620
# Epoch 45/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 14.9597 - mae: 2.7559 - val_loss: 37.1701 - val_mae: 4.2296
# Epoch 46/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 16.3546 - mae: 2.8432 - val_loss: 35.3990 - val_mae: 4.1729
# Epoch 47/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 15.5822 - mae: 2.7480 - val_loss: 35.5439 - val_mae: 4.1302
# Epoch 48/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 16.0676 - mae: 2.7106 - val_loss: 34.9069 - val_mae: 4.0873
# Epoch 49/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 15.7389 - mae: 2.8305 - val_loss: 35.7333 - val_mae: 4.0702
# Epoch 50/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 15.3814 - mae: 2.8077 - val_loss: 34.8525 - val_mae: 4.0390
# Epoch 51/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 14.4542 - mae: 2.7465 - val_loss: 34.4228 - val_mae: 3.9911
# Epoch 52/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 18.2479 - mae: 2.8869 - val_loss: 33.9363 - val_mae: 3.9527
# Epoch 53/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 18.9572 - mae: 2.8320 - val_loss: 35.4758 - val_mae: 3.9762
# Epoch 54/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 18.2063 - mae: 2.7694 - val_loss: 33.2580 - val_mae: 3.8888
# Epoch 55/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 19.2019 - mae: 2.8859 - val_loss: 32.8904 - val_mae: 3.8524
# Epoch 56/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 14.7323 - mae: 2.7299 - val_loss: 32.9037 - val_mae: 3.8112
# Epoch 57/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 15.1116 - mae: 2.7195 - val_loss: 32.3077 - val_mae: 3.7842
# Epoch 58/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 22.3163 - mae: 2.9059 - val_loss: 34.1377 - val_mae: 3.8512
# Epoch 59/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 12.0323 - mae: 2.5410 - val_loss: 30.8206 - val_mae: 3.7057
# Epoch 60/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 17.7465 - mae: 2.9188 - val_loss: 32.2923 - val_mae: 3.7286
# Epoch 61/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 15.6483 - mae: 2.5702 - val_loss: 31.7347 - val_mae: 3.6890
# Epoch 62/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 14.1014 - mae: 2.6438 - val_loss: 31.3272 - val_mae: 3.6553
# Epoch 63/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 13.9752 - mae: 2.5935 - val_loss: 31.3787 - val_mae: 3.6430
# Epoch 64/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 17.9120 - mae: 2.6717 - val_loss: 32.3781 - val_mae: 3.7034
# Epoch 65/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 15.0080 - mae: 2.4863 - val_loss: 30.7394 - val_mae: 3.5925
# Epoch 66/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 15.2494 - mae: 2.5997 - val_loss: 30.4451 - val_mae: 3.5614
# Epoch 67/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 13.2326 - mae: 2.4923 - val_loss: 29.7922 - val_mae: 3.5048
# Epoch 68/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 16.2856 - mae: 2.6959 - val_loss: 31.3889 - val_mae: 3.5714
# Epoch 69/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 12.5084 - mae: 2.4870 - val_loss: 29.6638 - val_mae: 3.4597
# Epoch 70/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 20.3406 - mae: 2.8754 - val_loss: 30.3174 - val_mae: 3.4660
# Epoch 71/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 16.2924 - mae: 2.7312 - val_loss: 29.3435 - val_mae: 3.4079
# Epoch 72/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 12.7877 - mae: 2.5377 - val_loss: 28.1461 - val_mae: 3.3505
# Epoch 73/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 14.2924 - mae: 2.5550 - val_loss: 28.9362 - val_mae: 3.3600
# Epoch 74/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 18.6550 - mae: 2.7844 - val_loss: 30.6854 - val_mae: 3.5058
# Epoch 75/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 13.9436 - mae: 2.4770 - val_loss: 26.7204 - val_mae: 3.2697
# Epoch 76/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 10.9568 - mae: 2.4394 - val_loss: 28.9352 - val_mae: 3.3132
# Epoch 77/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 14.3859 - mae: 2.5160 - val_loss: 26.7781 - val_mae: 3.2279
# Epoch 78/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 15.0865 - mae: 2.6554 - val_loss: 28.0869 - val_mae: 3.2684
# Epoch 79/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 12.3950 - mae: 2.3889 - val_loss: 26.7621 - val_mae: 3.2037
# Epoch 80/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 10.9652 - mae: 2.4180 - val_loss: 27.0895 - val_mae: 3.2168
# Epoch 81/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 12.9463 - mae: 2.4527 - val_loss: 26.7838 - val_mae: 3.2067
# Epoch 82/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 12.3267 - mae: 2.4044 - val_loss: 26.7016 - val_mae: 3.1950
# Epoch 83/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 11.5787 - mae: 2.4992 - val_loss: 25.5187 - val_mae: 3.1250
# Epoch 84/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 12.7280 - mae: 2.4976 - val_loss: 25.3845 - val_mae: 3.1210
# Epoch 85/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 13.4171 - mae: 2.5607 - val_loss: 26.0951 - val_mae: 3.1677
# Epoch 86/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 11.4454 - mae: 2.3849 - val_loss: 26.0850 - val_mae: 3.1455
# Epoch 87/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 15.6532 - mae: 2.5698 - val_loss: 25.8253 - val_mae: 3.1284
# Epoch 88/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 12.2594 - mae: 2.4137 - val_loss: 24.4569 - val_mae: 3.0361
# Epoch 89/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 18.9478 - mae: 2.6882 - val_loss: 26.5972 - val_mae: 3.1893
# Epoch 90/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 12.4352 - mae: 2.4404 - val_loss: 24.0002 - val_mae: 2.9923
# Epoch 91/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 12.3560 - mae: 2.4392 - val_loss: 24.9817 - val_mae: 3.0591
# Epoch 92/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 14.2850 - mae: 2.5293 - val_loss: 24.0771 - val_mae: 2.9910
# Epoch 93/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 11.4817 - mae: 2.3509 - val_loss: 23.1516 - val_mae: 2.9332
# Epoch 94/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 12.0197 - mae: 2.3366 - val_loss: 24.4689 - val_mae: 3.0382
# Epoch 95/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 13.1666 - mae: 2.4181 - val_loss: 24.1487 - val_mae: 3.0333
# Epoch 96/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 15.4134 - mae: 2.5302 - val_loss: 23.9610 - val_mae: 3.0098
# Epoch 97/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 14.1057 - mae: 2.5915 - val_loss: 25.1163 - val_mae: 3.0864
# Epoch 98/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 11.0539 - mae: 2.3244 - val_loss: 21.5160 - val_mae: 2.9024
# Epoch 99/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 13.8569 - mae: 2.5466 - val_loss: 23.8674 - val_mae: 3.0051
# Epoch 100/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 10.7435 - mae: 2.2945 - val_loss: 21.3487 - val_mae: 2.8375

# %%
mse_nn , mae_nn = model.evaluate(X_test,y_test)
print("Mean squared error on test data:",mse_nn)
print("Mean absolute error on test data: ",mae_nn)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 30.4335 - mae: 3.4256
# Mean squared error on test data: 22.601476669311523
# Mean absolute error on test data:  3.1023666858673096
